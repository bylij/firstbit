# %% [markdown]
# >https://ocw.mit.edu/courses/18-01sc-single-variable-calculus-fall-2010/resources/mit18_01scf10_ex02prb/

# %% [markdown]
# ### 问题
# - 函数 $f(x)=|x|$ 在 $x=0$ 点没有导数
# 导数的定义是曲线上一点处切线的斜率，而该函数在 $x=0$ 点不存在切线
# 函数曲线图：
# ![](data:image/png;base64,...)
