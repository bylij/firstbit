# %% [markdown]
# >https://ocw.mit.edu/courses/18-01sc-single-variable-calculus-fall-2010/resources/mit18_01scf10_ex56prb/

# %% [markdown]
# ### 问题
# - 两条曲线如下图所示：
# ![](data:image/png;base64,...)
# 根据定积分的几何定义可得图中阴影部分的面积 $S_A=\int_{-1}^1{[(\frac{1}{2}x^2-\frac{1}{2})-(x^4-1)]dx}=\int_{-1}^1{(-x^4+\frac{1}{2}x^2+\frac{1}{2})dx}=(-\frac{x^5}{5}+\frac{x^3}{6}+\frac{x}{2})|_{-1}^1=\frac{14}{15}$
