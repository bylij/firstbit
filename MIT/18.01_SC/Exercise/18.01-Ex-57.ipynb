# %% [markdown]
# >https://ocw.mit.edu/courses/18-01sc-single-variable-calculus-fall-2010/resources/mit18_01scf10_ex57prb/

# %% [markdown]
# ### 问题
# - a) 示意图如下：
# ![](data:image/png;base64,...)
# 采用圆盘法 $dV=\pi y^2dx=\pi (3x-x^2)^2dx\\
# \implies V=\int_0^3{(3x-x^2)^2dx}=\int_0^3{(x^4-6x^3+9x^2)dx}=(\frac{x^5}{5}-\frac{3x^4}{2}+3x^3)|_0^3=8.1$
# - b) 示意图如下：
# ![](data:image/png;base64,...)
# 采用圆盘法 $dV=\pi y^2dx \implies V=\int_0^a{axdx}=a \cdot (\frac{x^2}{2}|_0^a)=\frac{a^3}{2}$
