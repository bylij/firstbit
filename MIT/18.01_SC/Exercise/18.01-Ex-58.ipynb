# %% [markdown]
# >https://ocw.mit.edu/courses/18-01sc-single-variable-calculus-fall-2010/resources/mit18_01scf10_ex58prb/

# %% [markdown]
# ### 问题
# - 示意图如下：
# ![](data:image/png;base64,...)
# 选取右半部分进行旋转，可得 $dV=\pi x^2dy \implies V=\int_{-1}^1{\pi x^2dy}=\int_{-1}^1\pi{(4-4y^2)dy}=4\pi \cdot (y-\frac{y^3}{3})|_{-1}^1=\frac{16\pi}{3}$
