# %% [markdown]
# >https://ocw.mit.edu/courses/18-02sc-multivariable-calculus-fall-2010/resources/mit18_02sc_prac1a/

# %% [markdown]
# ## Practice Exam

# %% [markdown]
# ### 问题1
# - a) $\overrightarrow{OQ}=\hat{i}+\hat{j}+\hat{k}, \overrightarrow{OR}=\frac{1}{2}\hat{i}+\hat{j}+\frac{1}{2}\hat{k}$
# - b) $\cos{\theta}=\frac{\overrightarrow{OQ} \cdot \overrightarrow{OR}}{|\overrightarrow{OQ}||\overrightarrow{OR}|}=\frac{1 \cdot \frac{1}{2}+1 \cdot 1+1 \cdot \frac{1}{2}}{\sqrt{1^2+1^2+1^2} \cdot \sqrt{(\frac{1}{2})^2+1^2+(\frac{1}{2})^2}}=\frac{2\sqrt{2}}{3}$

# %% [markdown]
# ### 问题2
# - $\vec{v}=\frac{d\vec{R}}{dt}=-3\sin{t}\hat{i}+3\cos{t}\hat{j}+\hat{k}$
# $speed=|\vec{v}|=\sqrt{(-3\sin{t})^2+(3\cos{t})^2+1^2}=\sqrt{10}$

# %% [markdown]
# ### 问题3
# - a) $A=\begin{bmatrix}1&3&2\\2&0&-1\\1&1&0\end{bmatrix} \implies minors(A)=\begin{bmatrix}1&1&2\\-2&-2&-2\\-3&-5&-6\end{bmatrix} \implies cofactors(A)=\begin{bmatrix}1&-1&2\\2&-2&2\\-3&5&-6\end{bmatrix} \implies adj(A)=\begin{bmatrix}1&2&-3\\-1&-2&5\\2&2&-6\end{bmatrix}$
# 结合已知得 $a=2, b=-3$
# - b) $X=A^{-1}B=\begin{bmatrix}1/2&1&-3/2\\-1/2&-1&5/2\\1&1&-3\end{bmatrix}\begin{bmatrix}1\\-2\\1\end{bmatrix}=\begin{bmatrix}-3\\4\\-4\end{bmatrix}$
# - c) $M=\begin{bmatrix}1&3&c\\2&0&-1\\1&1&0\end{bmatrix}$
# $det(M)=\begin{vmatrix}1&3&c\\2&0&-1\\1&1&0\end{vmatrix}=0 \implies 1 \cdot [0-(-1)]-3 \cdot [0-(-1)]+c \cdot (2-0)=0 \implies c=1$
# $\vec{U}=<1,3,1>, \vec{V}=<2,0,-1>, \vec{W}=<1,1,0>$，由 $det(M)=0$ 可知 $\vec{U}, \vec{V}, \vec{W}$ 在同一平面，只考虑 $\vec{U}, \vec{V}$ 即可
# $\vec{U} \cdot \vec{X}=0, \vec{V} \cdot \vec{X}=0$ 可通过 $\vec{X}=\vec{U} \times \vec{V}$ 计算得 $\vec{X}$
# $\vec{X}=<1,3,1> \times <2,0,-1>=\begin{vmatrix}\hat{i}&\hat{j}&\hat{k}\\1&3&1\\2&0&-1\end{vmatrix}=<-3,3,-6>$
# 即 $X=\begin{bmatrix}-3\\3\\-6\end{bmatrix}$ 是一个解

# %% [markdown]
# ### 问题4
# - 示意图如下
# ![](data:image/png;base64,...)
# $\vec{r}=\overrightarrow{OP}=\frac{1}{2}(\overrightarrow{OA}+\overrightarrow{OB})=\frac{1}{2}(<0,L\sin{\theta}>+<-L\cos{\theta}, 0>)=<-\frac{L}{2}\cos{\theta},\frac{L}{2}\sin{\theta}>$
# 点P 轨迹的参数方程 $\begin{cases}x(\theta)=-\frac{L}{2}\cos{\theta}\\y(\theta)=\frac{L}{2}\sin{\theta}\end{cases}$

# %% [markdown]
# ### 问题5
# - a) 示意图如下
# ![](data:image/png;base64,...)
# $\cos{\theta}=\frac{\overrightarrow{P_0P_1} \cdot \overrightarrow{P_0P_2}}{|\overrightarrow{P_0P_1}||\overrightarrow{P_0P_2}|}=\frac{<-1,-1,1> \cdot <0,-2,1>}{\sqrt{(-1)^2+(-1)^2+1^2} \cdot \sqrt{0^2+(-2)^2+1^2}}=\sqrt{\frac{3}{5}} \implies \sin{\theta}=\sqrt{1-\cos^2{\theta}}=\sqrt{\frac{2}{5}}$
# $S_{\triangle{P_0P_1P_2}}=|\frac{1}{2}|\overrightarrow{P_0P_2}||\overrightarrow{P_0P_1}|\sin{\theta}|=|\frac{1}{2} \cdot \sqrt{3} \cdot \sqrt{5} \cdot \sqrt{\frac{2}{5}}|=\frac{\sqrt{6}}{2}$
# - b) 平面法向量 $\vec{N}=\overrightarrow{P_0P_1} \times \overrightarrow{P_0P_2}=<-1,-1,1> \times <0,-2,1>=\begin{vmatrix}\hat{i}&\hat{j}&\hat{k}\\-1&-1&1\\0&-2&1\end{vmatrix}=<1,1,2>$
# 法点方程 $(x-2)+(y-1)+2(y-0)=0 \implies x+y+2z=3$
# - c) 直线的参数方程 $\begin{cases}x(t)=-1+t\\y(t)=t\\z(t)=t\end{cases}$ 带入到 b) 中平面方程 $(-1+t)+t+2t=3 \implies t=1$ 带入参数方程得到交点 $(0, 1, 1)$

# %% [markdown]
# ### 问题6
# - a) $\frac{d}{dt}(\vec{R} \cdot \vec{R})=\frac{d\vec{R}}{dt} \cdot \vec{R}+\vec{R} \cdot \frac{d\vec{R}}{dt}=2\vec{R} \cdot \frac{d\vec{R}}{dt}=2\vec{R} \cdot \vec{V}$
# - b) $|\vec{R}|$ 是常数，则 $\frac{d}{dt}(\vec{R} \cdot \vec{R})=\frac{d}{dt}|\vec{R}|^2=0 \implies 2\vec{R} \cdot \vec{V}=0 \implies \vec{R} \cdot \vec{V}=0 \implies \vec{R} \perp \vec{V}$
# - c) 根据 b) 中结论 $\vec{R} \cdot \vec{V}=0 \implies \frac{d}{dt}(\vec{R} \cdot \vec{V})=\frac{\vec{R}}{dt} \cdot \vec{V}+\vec{R} \cdot \frac{\vec{V}}{dt}=0 \implies \vec{v} \cdot \vec{v}+\vec{R} \cdot \vec{A}=0 \implies \vec{R} \cdot \vec{A}=-\vec{V} \cdot \vec{V}=-|\vec{V}|^2$

# %% [markdown]
# >https://ocw.mit.edu/courses/18-02sc-multivariable-calculus-fall-2010/resources/mit18_02sc_exam1/

# %% [markdown]
# ## Exam

# %% [markdown]
# ### 问题1
# - a) $P=(1, 0, 0), Q=(0, 2, 0), R=(0, 0, 3)$
# $\overrightarrow{QP}=\hat{i}-2\hat{j}, \overrightarrow{QR}=-2\hat{j}+3\hat{k}$
# - b) $\cos{\theta}=\frac{\overrightarrow{QP} \cdot \overrightarrow{QR}}{|\overrightarrow{QP}||\overrightarrow{QP}|}=\frac{<1,-2,0> \cdot <0,-2,3>}{\sqrt{1^2+(-2)^2+0^2} \cdot \sqrt{0^2+(-2)^2+3^2}}=\frac{4}{\sqrt{65}}$

# %% [markdown]
# ### 问题2
# - a) $\overrightarrow{QP}=<1,-2,0>, \overrightarrow{QR}=<0,-2,3>$
# $\cos{\theta}=\frac{\overrightarrow{QP} \cdot \overrightarrow{QR}}{|\overrightarrow{QP}||\overrightarrow{QP}|}=\frac{<1,-2,0> \cdot <0,-2,3>}{\sqrt{1^2+(-2)^2+0^2} \cdot \sqrt{0^2+(-2)^2+3^2}}=\frac{4}{\sqrt{65}} \implies \sin{\theta}=\sqrt{1-\cos^2{\theta}}=\frac{7}{\sqrt{65}}$
# $S_{\triangle{PQR}}=|\frac{1}{2}|\overrightarrow{QP}||\overrightarrow{QR}|\sin{\theta}|=|\frac{1}{2} \cdot \sqrt{5} \cdot \sqrt{13} \cdot \frac{7}{\sqrt{65}}|=\frac{7}{2}$
# - b) 平面法向量 $\vec{N}=\overrightarrow{QP} \times \overrightarrow{QR}=<1,-2,0> \times <0,-2,3>=\begin{vmatrix}\hat{i}&\hat{j}&\hat{k}\\1&-2&0\\0&-2&3\end{vmatrix}=<-6,-3,-2>$
# 法点方程 $-6(x-1)-3(y-1)-2(z-1)=0 \implies 6x+3y+2z=11$
# - c) 直线方向向量 $<1,0,-3>$ 可得直线参数方程 $\begin{cases}x(t)=1+t\\y(t)=2\\z(t)=3-3t\end{cases}$
# 带入到 b) 中平面方程 $6(1+t)+3 \cdot 2+2(3-3t)=11 \implies 18=11$ 得到 $t$ 无解，可知直线与平面无交点

# %% [markdown]
# ### 问题3
# - 示意图如下
# ![](data:image/png;base64,...)
# - a) $\overrightarrow{OP}=\overrightarrow{OA}+\overrightarrow{AP} \implies \vec{r}=<10t,0>+<\cos{t},\sin{t}>=<10t+\cos{t},\sin{t}>$
# 当 $t=\pi$ 时到达背面，$\vec{r}=<10\pi-1，0>$，即位置在 $(10\pi-1, 0)$ 点
# - b) $\vec{v}=\frac{d\vec{r}}{dt}=<10-\sin{t}, \cos{t}>$
# $speed=|\vec{v}|=\sqrt{(10-\sin{t})^2+(\cos{t})^2}=\sqrt{101-20\sin{t}}$ 可知 $t=0, \pi$ 时取最大值，$t=\frac{\pi}{2}$ 时取最小值

# %% [markdown]
# ### 问题4
# - a) $det(M)=\begin{vmatrix}1&2&3\\3&2&1\\2&-1&-1\end{vmatrix}=1 \cdot [(2 \cdot -1)-(1 \cdot -1)]-2 \cdot [3 \cdot (-1)-1 \cdot 2]+3 \cdot [3 \cdot (-1)-2 \cdot 2]=-12$
# - b) $minors(M)=\begin{pmatrix}-1&-5&-7\\1&-7&-5\\-4&-8&-4\end{pmatrix} \implies cofactors(M)=\begin{pmatrix}-1&5&-7\\-1&-7&5\\-4&8&-4\end{pmatrix} \implies adj(M)=\begin{pmatrix}-1&-1&-4\\5&-7&8\\-7&5&-4\end{pmatrix}$
# 对比已知可得 $a=-5, b=7$
# - c) $\begin{pmatrix}x\\y\\z\end{pmatrix}=M^{-1}\begin{pmatrix}0\\t\\3\end{pmatrix}=\frac{1}{12}\begin{pmatrix}1&1&4\\-5&7&-8\\7&-5&4\end{pmatrix}\begin{pmatrix}0\\t\\3\end{pmatrix}=\begin{pmatrix}t/12+1\\7t/12-2\\-5t/12+1\end{pmatrix} \implies \vec{r}=<\frac{t}{12}+1,\frac{7t}{12}-2,-\frac{5t}{12}+1>$
# - d) $\frac{d\vec{r}}{dt}=<\frac{1}{12},\frac{7}{12},-\frac{5}{12}>$

# %% [markdown]
# ### 问题5
# - a) $\vec{N}=<4,-3,-2>, \vec{r}=<x, y, z>$
# $4x-3y-2z=6 \implies <x, y, z> \cdot <4, -3, -2>=6 \implies \vec{r} \cdot \vec{N}=6$
# - b) $\vec{r} \cdot \vec{N}=6 \implies \frac{d}{dt}(\vec{r} \cdot \vec{N})=0\\
# \implies \frac{d\vec{r}}{dt} \cdot \vec{N}+\vec{r} \cdot \frac{d\vec{N}}{dt}=0\\
# \implies \frac{d\vec{r}}{dt} \cdot \vec{N}+\vec{r} \cdot 0=0\\
# \implies \frac{d\vec{r}}{dt} \cdot \vec{N}=0\\
# \implies \frac{d\vec{r}}{dt} \perp \vec{N}$ 命题成立
