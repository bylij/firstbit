# %% [markdown]
# >https://ocw.mit.edu/courses/18-02sc-multivariable-calculus-fall-2010/resources/mit18_02sc_pb_5_quest/

# %% [markdown]
# ### 问题1
# - a) $\begin{vmatrix}1&2\\3&4\end{vmatrix}=1 \cdot 4-2 \cdot 3=-2$
# - b) $\begin{vmatrix}1&-2\\-3&4\end{vmatrix}=1 \cdot 4-(-2) \cdot (-3)=-2$
# - c) $\begin{vmatrix}3&4\\1&2\end{vmatrix}=3 \cdot 2-4 \cdot 1=2$

# %% [markdown]
# ### 问题2
# - 四边形 OABC 如下图
# ![](data:image/png;base64,...)
# $S_{OABC}=S_{OAB}+S_{OBC}\\
# =|\det(\overrightarrow{OA}, \overrightarrow{OB})|+|\det(\overrightarrow{OB}, \overrightarrow{OC})|\\
# =|\det(<1, 2>, <4, 3>)|+|\det(<4, 3>, <3, -1>)|\\
# =|1 \cdot 3-2 \cdot 4|+|4 \cdot (-1)-3 \cdot 3|\\
# =|-5|+|-13|=18$
